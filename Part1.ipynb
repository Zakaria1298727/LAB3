# %% [markdown]
# <a href="https://colab.research.google.com/github/Zakaria1298727/LAB3/blob/main/Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
from bs4 import BeautifulSoup
import re
import csv
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Étape 1 : Scraping
def scrape_arabic_text_from_page(page_number):
    url = f"https://www.kooora.com/?n=0&o=n&pg={page_number}"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve page {page_number}. Status code: {response.status_code}")
        return None

    soup = BeautifulSoup(response.text, "html.parser")

    # Find all text content from the website
    all_text = soup.find_all(text=True)

    # Regular expression to match Arabic text
    arabic_text_pattern = re.compile(r"[\u0600-\u06FF]+")

    # Extract and filter only Arabic text
    arabic_text = []
    for text in all_text:
        matches = arabic_text_pattern.findall(text)
        if matches:
            arabic_text.append(" ".join(matches))

    return " ".join(arabic_text)

def save_text_to_file(text, filename):
    if not text:
        print(f"No text found to save in {filename}.")
        return

    with open(filename, "w", encoding="utf-8-sig") as file:
        file.write(text)
    print(f"Saved text to {filename}")

# Étape 2 : Charger et analyser les fichiers
def load_text_files(folder_path):
    """Load text content from all files in a given folder."""
    file_contents = {}
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            with open(os.path.join(folder_path, filename), "r", encoding="utf-8") as file:
                file_contents[filename] = file.read()
    return file_contents

def calculate_similarity(file_contents):
    """Calculate pairwise similarity scores between text files."""
    filenames = list(file_contents.keys())
    texts = list(file_contents.values())

    # Compute TF-IDF vectors
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(texts)

    # Compute cosine similarity
    similarity_matrix = cosine_similarity(tfidf_matrix)

    # Normalize scores to a scale of 0 to 10
    normalized_scores = np.interp(similarity_matrix, (similarity_matrix.min(), similarity_matrix.max()), (0, 10))

    # Assign an average similarity score to each file
    scores = {filenames[i]: round(np.mean(normalized_scores[i]), 2) for i in range(len(filenames))}
    return scores

# Étape 3 : Créer le dataset CSV
def create_dataset_csv(file_contents, scores, output_file="dataset.csv"):
    with open(output_file, "w", encoding="utf-8-sig", newline="") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["Filename", "Content", "Score"])
        for filename, content in file_contents.items():
            writer.writerow([filename, content, scores.get(filename, 0)])
    print(f"Dataset saved to {output_file}")

def main():
    # Scraping and saving data
    folder_path = "scraped_pages"
    os.makedirs(folder_path, exist_ok=True)

    for i in range(2, 500):
        print(f"Scraping page {i}...")
        text = scrape_arabic_text_from_page(i)
        if text:
            save_text_to_file(text, os.path.join(folder_path, f"page_{i}.txt"))

    # Analyzing similarities
    print("Analyzing similarities...")
    file_contents = load_text_files(folder_path)
    if not file_contents:
        print("No files to analyze.")
        return

    scores = calculate_similarity(file_contents)

    # Creating the dataset
    print("Creating dataset...")
    create_dataset_csv(file_contents, scores)

if __name__ == "__main__":
    main()
# Out:
# Scraping page 2...
# <ipython-input-1-bc33e56a645a>:21: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   all_text = soup.find_all(text=True)
# Saved text to scraped_pages/page_2.txt
# Scraping page 3...
# Saved text to scraped_pages/page_3.txt
# Scraping page 4...
# Saved text to scraped_pages/page_4.txt
# Scraping page 5...
# Saved text to scraped_pages/page_5.txt
# Scraping page 6...
# Saved text to scraped_pages/page_6.txt
# Scraping page 7...
# Saved text to scraped_pages/page_7.txt
# Scraping page 8...
# Saved text to scraped_pages/page_8.txt
# Scraping page 9...
# Saved text to scraped_pages/page_9.txt
# Scraping page 10...
# Saved text to scraped_pages/page_10.txt
# Scraping page 11...
# Saved text to scraped_pages/page_11.txt
# Scraping page 12...
# Saved text to scraped_pages/page_12.txt
# Scraping page 13...
# Saved text to scraped_pages/page_13.txt
# Scraping page 14...
# Saved text to scraped_pages/page_14.txt
# Scraping page 15...
# Saved text to scraped_pages/page_15.txt
# Scraping page 16...
# Saved text to scraped_pages/page_16.txt
# Scraping page 17...
# Saved text to scraped_pages/page_17.txt
# Scraping page 18...
# Saved text to scraped_pages/page_18.txt
# Scraping page 19...
# Saved text to scraped_pages/page_19.txt
# Scraping page 20...
# Saved text to scraped_pages/page_20.txt
# Scraping page 21...
# Saved text to scraped_pages/page_21.txt
# Scraping page 22...
# Saved text to scraped_pages/page_22.txt
# Scraping page 23...
# Saved text to scraped_pages/page_23.txt
# Scraping page 24...
# Saved text to scraped_pages/page_24.txt
# Scraping page 25...
# Saved text to scraped_pages/page_25.txt
# Scraping page 26...
# Saved text to scraped_pages/page_26.txt
# Scraping page 27...
# Saved text to scraped_pages/page_27.txt
# Scraping page 28...
# Saved text to scraped_pages/page_28.txt
# Scraping page 29...
# Saved text to scraped_pages/page_29.txt
# Scraping page 30...
# Saved text to scraped_pages/page_30.txt
# Scraping page 31...
# Saved text to scraped_pages/page_31.txt
# Scraping page 32...
# Saved text to scraped_pages/page_32.txt
# Scraping page 33...
# Saved text to scraped_pages/page_33.txt
# Scraping page 34...
# Saved text to scraped_pages/page_34.txt
# Scraping page 35...
# Saved text to scraped_pages/page_35.txt
# Scraping page 36...
# Saved text to scraped_pages/page_36.txt
# Scraping page 37...
# Saved text to scraped_pages/page_37.txt
# Scraping page 38...
# Saved text to scraped_pages/page_38.txt
# Scraping page 39...
# Saved text to scraped_pages/page_39.txt
# Scraping page 40...
# Saved text to scraped_pages/page_40.txt
# Scraping page 41...
# Saved text to scraped_pages/page_41.txt
# Scraping page 42...
# Saved text to scraped_pages/page_42.txt
# Scraping page 43...
# Saved text to scraped_pages/page_43.txt
# Scraping page 44...
# Saved text to scraped_pages/page_44.txt
# Scraping page 45...
# Saved text to scraped_pages/page_45.txt
# Scraping page 46...
# Saved text to scraped_pages/page_46.txt
# Scraping page 47...
# Saved text to scraped_pages/page_47.txt
# Scraping page 48...
# Saved text to scraped_pages/page_48.txt
# Scraping page 49...
# Saved text to scraped_pages/page_49.txt
# Scraping page 50...
# Saved text to scraped_pages/page_50.txt
# Scraping page 51...
# Saved text to scraped_pages/page_51.txt
# Scraping page 52...
# Saved text to scraped_pages/page_52.txt
# Scraping page 53...
# Saved text to scraped_pages/page_53.txt
# Scraping page 54...
# Saved text to scraped_pages/page_54.txt
# Scraping page 55...
# Saved text to scraped_pages/page_55.txt
# Scraping page 56...
# Saved text to scraped_pages/page_56.txt
# Scraping page 57...
# Saved text to scraped_pages/page_57.txt
# Scraping page 58...
# Saved text to scraped_pages/page_58.txt
# Scraping page 59...
# Saved text to scraped_pages/page_59.txt
# Scraping page 60...
# Saved text to scraped_pages/page_60.txt
# Scraping page 61...
# Saved text to scraped_pages/page_61.txt
# Scraping page 62...
# Saved text to scraped_pages/page_62.txt
# Scraping page 63...
# Saved text to scraped_pages/page_63.txt
# Scraping page 64...
# Saved text to scraped_pages/page_64.txt
# Scraping page 65...
# Saved text to scraped_pages/page_65.txt
# Scraping page 66...
# Saved text to scraped_pages/page_66.txt
# Scraping page 67...
# Saved text to scraped_pages/page_67.txt
# Scraping page 68...
# Saved text to scraped_pages/page_68.txt
# Scraping page 69...
# Saved text to scraped_pages/page_69.txt
# Scraping page 70...
# Saved text to scraped_pages/page_70.txt
# Scraping page 71...
# Saved text to scraped_pages/page_71.txt
# Scraping page 72...
# Saved text to scraped_pages/page_72.txt
# Scraping page 73...
# Saved text to scraped_pages/page_73.txt
# Scraping page 74...
# Saved text to scraped_pages/page_74.txt
# Scraping page 75...
# Saved text to scraped_pages/page_75.txt
# Scraping page 76...
# Saved text to scraped_pages/page_76.txt
# Scraping page 77...
# Saved text to scraped_pages/page_77.txt
# Scraping page 78...
# Saved text to scraped_pages/page_78.txt
# Scraping page 79...
# Saved text to scraped_pages/page_79.txt
# Scraping page 80...
# Saved text to scraped_pages/page_80.txt
# Scraping page 81...
# Saved text to scraped_pages/page_81.txt
# Scraping page 82...
# Saved text to scraped_pages/page_82.txt
# Scraping page 83...
# Saved text to scraped_pages/page_83.txt
# Scraping page 84...
# Saved text to scraped_pages/page_84.txt
# Scraping page 85...
# Saved text to scraped_pages/page_85.txt
# Scraping page 86...
# Saved text to scraped_pages/page_86.txt
# Scraping page 87...
# Saved text to scraped_pages/page_87.txt
# Scraping page 88...
# Saved text to scraped_pages/page_88.txt
# Scraping page 89...
# Saved text to scraped_pages/page_89.txt
# Scraping page 90...
# Saved text to scraped_pages/page_90.txt
# Scraping page 91...
# Saved text to scraped_pages/page_91.txt
# Scraping page 92...
# Saved text to scraped_pages/page_92.txt
# Scraping page 93...
# Saved text to scraped_pages/page_93.txt
# Scraping page 94...
# Saved text to scraped_pages/page_94.txt
# Scraping page 95...
# Saved text to scraped_pages/page_95.txt
# Scraping page 96...
# Saved text to scraped_pages/page_96.txt
# Scraping page 97...
# Saved text to scraped_pages/page_97.txt
# Scraping page 98...
# Saved text to scraped_pages/page_98.txt
# Scraping page 99...
# Saved text to scraped_pages/page_99.txt
# Scraping page 100...
# Saved text to scraped_pages/page_100.txt
# Scraping page 101...
# Saved text to scraped_pages/page_101.txt
# Scraping page 102...
# Saved text to scraped_pages/page_102.txt
# Scraping page 103...
# Saved text to scraped_pages/page_103.txt
# Scraping page 104...
# Saved text to scraped_pages/page_104.txt
# Scraping page 105...
# Saved text to scraped_pages/page_105.txt
# Scraping page 106...
# Saved text to scraped_pages/page_106.txt
# Scraping page 107...
# Saved text to scraped_pages/page_107.txt
# Scraping page 108...
# Saved text to scraped_pages/page_108.txt
# Scraping page 109...
# Saved text to scraped_pages/page_109.txt
# Scraping page 110...
# Saved text to scraped_pages/page_110.txt
# Scraping page 111...
# Saved text to scraped_pages/page_111.txt
# Scraping page 112...
# Saved text to scraped_pages/page_112.txt
# Scraping page 113...
# Saved text to scraped_pages/page_113.txt
# Scraping page 114...
# Saved text to scraped_pages/page_114.txt
# Scraping page 115...
# Saved text to scraped_pages/page_115.txt
# Scraping page 116...
# Saved text to scraped_pages/page_116.txt
# Scraping page 117...
# Saved text to scraped_pages/page_117.txt
# Scraping page 118...
# Saved text to scraped_pages/page_118.txt
# Scraping page 119...
# Saved text to scraped_pages/page_119.txt
# Scraping page 120...
# Saved text to scraped_pages/page_120.txt
# Scraping page 121...
# Saved text to scraped_pages/page_121.txt
# Scraping page 122...
# Saved text to scraped_pages/page_122.txt
# Scraping page 123...
# Saved text to scraped_pages/page_123.txt
# Scraping page 124...
# Saved text to scraped_pages/page_124.txt
# Scraping page 125...
# Saved text to scraped_pages/page_125.txt
# Scraping page 126...
# Saved text to scraped_pages/page_126.txt
# Scraping page 127...
# Saved text to scraped_pages/page_127.txt
# Scraping page 128...
# Saved text to scraped_pages/page_128.txt
# Scraping page 129...
# Saved text to scraped_pages/page_129.txt
# Scraping page 130...
# Saved text to scraped_pages/page_130.txt
# Scraping page 131...
# Saved text to scraped_pages/page_131.txt
# Scraping page 132...
# Saved text to scraped_pages/page_132.txt
# Scraping page 133...
# Saved text to scraped_pages/page_133.txt
# Scraping page 134...
# Saved text to scraped_pages/page_134.txt
# Scraping page 135...
# Saved text to scraped_pages/page_135.txt
# Scraping page 136...
# Saved text to scraped_pages/page_136.txt
# Scraping page 137...
# Saved text to scraped_pages/page_137.txt
# Scraping page 138...
# Saved text to scraped_pages/page_138.txt
# Scraping page 139...
# Saved text to scraped_pages/page_139.txt
# Scraping page 140...
# Saved text to scraped_pages/page_140.txt
# Scraping page 141...
# Saved text to scraped_pages/page_141.txt
# Scraping page 142...
# Saved text to scraped_pages/page_142.txt
# Scraping page 143...
# Saved text to scraped_pages/page_143.txt
# Scraping page 144...
# Saved text to scraped_pages/page_144.txt
# Scraping page 145...
# Saved text to scraped_pages/page_145.txt
# Scraping page 146...
# Saved text to scraped_pages/page_146.txt
# Scraping page 147...
# Saved text to scraped_pages/page_147.txt
# Scraping page 148...
# Saved text to scraped_pages/page_148.txt
# Scraping page 149...
# Saved text to scraped_pages/page_149.txt
# Scraping page 150...
# Saved text to scraped_pages/page_150.txt
# Scraping page 151...
# Saved text to scraped_pages/page_151.txt
# Scraping page 152...
# Saved text to scraped_pages/page_152.txt
# Scraping page 153...
# Saved text to scraped_pages/page_153.txt
# Scraping page 154...
# Saved text to scraped_pages/page_154.txt
# Scraping page 155...
# Saved text to scraped_pages/page_155.txt
# Scraping page 156...
# Saved text to scraped_pages/page_156.txt
# Scraping page 157...
# Saved text to scraped_pages/page_157.txt
# Scraping page 158...
# Saved text to scraped_pages/page_158.txt
# Scraping page 159...
# Saved text to scraped_pages/page_159.txt
# Scraping page 160...
# Saved text to scraped_pages/page_160.txt
# Scraping page 161...
# Saved text to scraped_pages/page_161.txt
# Scraping page 162...
# Saved text to scraped_pages/page_162.txt
# Scraping page 163...
# Saved text to scraped_pages/page_163.txt
# Scraping page 164...
# Saved text to scraped_pages/page_164.txt
# Scraping page 165...
# Saved text to scraped_pages/page_165.txt
# Scraping page 166...
# Saved text to scraped_pages/page_166.txt
# Scraping page 167...
# Saved text to scraped_pages/page_167.txt
# Scraping page 168...
# Saved text to scraped_pages/page_168.txt
# Scraping page 169...
# Saved text to scraped_pages/page_169.txt
# Scraping page 170...
# Saved text to scraped_pages/page_170.txt
# Scraping page 171...
# Saved text to scraped_pages/page_171.txt
# Scraping page 172...
# Saved text to scraped_pages/page_172.txt
# Scraping page 173...
# Saved text to scraped_pages/page_173.txt
# Scraping page 174...
# Saved text to scraped_pages/page_174.txt
# Scraping page 175...
# Saved text to scraped_pages/page_175.txt
# Scraping page 176...
# Saved text to scraped_pages/page_176.txt
# Scraping page 177...
# Saved text to scraped_pages/page_177.txt
# Scraping page 178...
# Saved text to scraped_pages/page_178.txt
# Scraping page 179...
# Saved text to scraped_pages/page_179.txt
# Scraping page 180...
# Saved text to scraped_pages/page_180.txt
# Scraping page 181...
# Saved text to scraped_pages/page_181.txt
# Scraping page 182...
# Saved text to scraped_pages/page_182.txt
# Scraping page 183...
# Saved text to scraped_pages/page_183.txt
# Scraping page 184...
# Saved text to scraped_pages/page_184.txt
# Scraping page 185...
# Saved text to scraped_pages/page_185.txt
# Scraping page 186...
# Saved text to scraped_pages/page_186.txt
# Scraping page 187...
# Saved text to scraped_pages/page_187.txt
# Scraping page 188...
# Saved text to scraped_pages/page_188.txt
# Scraping page 189...
# Saved text to scraped_pages/page_189.txt
# Scraping page 190...
# Saved text to scraped_pages/page_190.txt
# Scraping page 191...
# Saved text to scraped_pages/page_191.txt
# Scraping page 192...
# Saved text to scraped_pages/page_192.txt
# Scraping page 193...
# Saved text to scraped_pages/page_193.txt
# Scraping page 194...
# Saved text to scraped_pages/page_194.txt
# Scraping page 195...
# Saved text to scraped_pages/page_195.txt
# Scraping page 196...
# Saved text to scraped_pages/page_196.txt
# Scraping page 197...
# Saved text to scraped_pages/page_197.txt
# Scraping page 198...
# Saved text to scraped_pages/page_198.txt
# Scraping page 199...
# Saved text to scraped_pages/page_199.txt
# Scraping page 200...
# Saved text to scraped_pages/page_200.txt
# Scraping page 201...
# Saved text to scraped_pages/page_201.txt
# Scraping page 202...
# Saved text to scraped_pages/page_202.txt
# Scraping page 203...
# Saved text to scraped_pages/page_203.txt
# Scraping page 204...
# Saved text to scraped_pages/page_204.txt
# Scraping page 205...
# Saved text to scraped_pages/page_205.txt
# Scraping page 206...
# Saved text to scraped_pages/page_206.txt
# Scraping page 207...
# Saved text to scraped_pages/page_207.txt
# Scraping page 208...
# Saved text to scraped_pages/page_208.txt
# Scraping page 209...
# Saved text to scraped_pages/page_209.txt
# Scraping page 210...
# Saved text to scraped_pages/page_210.txt
# Scraping page 211...
# Saved text to scraped_pages/page_211.txt
# Scraping page 212...
# Saved text to scraped_pages/page_212.txt
# Scraping page 213...
# Saved text to scraped_pages/page_213.txt
# Scraping page 214...
# Saved text to scraped_pages/page_214.txt
# Scraping page 215...
# Saved text to scraped_pages/page_215.txt
# Scraping page 216...
# Saved text to scraped_pages/page_216.txt
# Scraping page 217...
# Saved text to scraped_pages/page_217.txt
# Scraping page 218...
# Saved text to scraped_pages/page_218.txt
# Scraping page 219...
# Saved text to scraped_pages/page_219.txt
# Scraping page 220...
# Saved text to scraped_pages/page_220.txt
# Scraping page 221...
# Saved text to scraped_pages/page_221.txt
# Scraping page 222...
# Saved text to scraped_pages/page_222.txt
# Scraping page 223...
# Saved text to scraped_pages/page_223.txt
# Scraping page 224...
# Saved text to scraped_pages/page_224.txt
# Scraping page 225...
# Saved text to scraped_pages/page_225.txt
# Scraping page 226...
# Saved text to scraped_pages/page_226.txt
# Scraping page 227...
# Saved text to scraped_pages/page_227.txt
# Scraping page 228...
# Saved text to scraped_pages/page_228.txt
# Scraping page 229...
# Saved text to scraped_pages/page_229.txt
# Scraping page 230...
# Saved text to scraped_pages/page_230.txt
# Scraping page 231...
# Saved text to scraped_pages/page_231.txt
# Scraping page 232...
# Saved text to scraped_pages/page_232.txt
# Scraping page 233...
# Saved text to scraped_pages/page_233.txt
# Scraping page 234...
# Saved text to scraped_pages/page_234.txt
# Scraping page 235...
# Saved text to scraped_pages/page_235.txt
# Scraping page 236...
# Saved text to scraped_pages/page_236.txt
# Scraping page 237...
# Saved text to scraped_pages/page_237.txt
# Scraping page 238...
# Saved text to scraped_pages/page_238.txt
# Scraping page 239...
# Saved text to scraped_pages/page_239.txt
# Scraping page 240...
# Saved text to scraped_pages/page_240.txt
# Scraping page 241...
# Saved text to scraped_pages/page_241.txt
# Scraping page 242...
# Saved text to scraped_pages/page_242.txt
# Scraping page 243...
# Saved text to scraped_pages/page_243.txt
# Scraping page 244...
# Saved text to scraped_pages/page_244.txt
# Scraping page 245...
# Saved text to scraped_pages/page_245.txt
# Scraping page 246...
# Saved text to scraped_pages/page_246.txt
# Scraping page 247...
# Saved text to scraped_pages/page_247.txt
# Scraping page 248...
# Saved text to scraped_pages/page_248.txt
# Scraping page 249...
# Saved text to scraped_pages/page_249.txt
# Scraping page 250...
# Saved text to scraped_pages/page_250.txt
# Scraping page 251...
# Saved text to scraped_pages/page_251.txt
# Scraping page 252...
# Saved text to scraped_pages/page_252.txt
# Scraping page 253...
# Saved text to scraped_pages/page_253.txt
# Scraping page 254...
# Saved text to scraped_pages/page_254.txt
# Scraping page 255...
# Saved text to scraped_pages/page_255.txt
# Scraping page 256...
# Saved text to scraped_pages/page_256.txt
# Scraping page 257...
# Saved text to scraped_pages/page_257.txt
# Scraping page 258...
# Saved text to scraped_pages/page_258.txt
# Scraping page 259...
# Saved text to scraped_pages/page_259.txt
# Scraping page 260...
# Saved text to scraped_pages/page_260.txt
# Scraping page 261...
# Saved text to scraped_pages/page_261.txt
# Scraping page 262...
# Saved text to scraped_pages/page_262.txt
# Scraping page 263...
# Saved text to scraped_pages/page_263.txt
# Scraping page 264...
# Saved text to scraped_pages/page_264.txt
# Scraping page 265...
# Saved text to scraped_pages/page_265.txt
# Scraping page 266...
# Saved text to scraped_pages/page_266.txt
# Scraping page 267...
# Saved text to scraped_pages/page_267.txt
# Scraping page 268...
# Saved text to scraped_pages/page_268.txt
# Scraping page 269...
# Saved text to scraped_pages/page_269.txt
# Scraping page 270...
# Saved text to scraped_pages/page_270.txt
# Scraping page 271...
# Saved text to scraped_pages/page_271.txt
# Scraping page 272...
# Saved text to scraped_pages/page_272.txt
# Scraping page 273...
# Saved text to scraped_pages/page_273.txt
# Scraping page 274...
# Saved text to scraped_pages/page_274.txt
# Scraping page 275...
# Saved text to scraped_pages/page_275.txt
# Scraping page 276...
# Saved text to scraped_pages/page_276.txt
# Scraping page 277...
# Saved text to scraped_pages/page_277.txt
# Scraping page 278...
# Saved text to scraped_pages/page_278.txt
# Scraping page 279...
# Saved text to scraped_pages/page_279.txt
# Scraping page 280...
# Saved text to scraped_pages/page_280.txt
# Scraping page 281...
# Saved text to scraped_pages/page_281.txt
# Scraping page 282...
# Saved text to scraped_pages/page_282.txt
# Scraping page 283...
# Saved text to scraped_pages/page_283.txt
# Scraping page 284...
# Saved text to scraped_pages/page_284.txt
# Scraping page 285...
# Saved text to scraped_pages/page_285.txt
# Scraping page 286...
# Saved text to scraped_pages/page_286.txt
# Scraping page 287...
# Saved text to scraped_pages/page_287.txt
# Scraping page 288...
# Saved text to scraped_pages/page_288.txt
# Scraping page 289...
# Saved text to scraped_pages/page_289.txt
# Scraping page 290...
# Saved text to scraped_pages/page_290.txt
# Scraping page 291...
# Saved text to scraped_pages/page_291.txt
# Scraping page 292...
# Saved text to scraped_pages/page_292.txt
# Scraping page 293...
# Saved text to scraped_pages/page_293.txt
# Scraping page 294...
# Saved text to scraped_pages/page_294.txt
# Scraping page 295...
# Saved text to scraped_pages/page_295.txt
# Scraping page 296...
# Saved text to scraped_pages/page_296.txt
# Scraping page 297...
# Saved text to scraped_pages/page_297.txt
# Scraping page 298...
# Saved text to scraped_pages/page_298.txt
# Scraping page 299...
# Saved text to scraped_pages/page_299.txt
# Scraping page 300...
# Saved text to scraped_pages/page_300.txt
# Scraping page 301...
# Saved text to scraped_pages/page_301.txt
# Scraping page 302...
# Saved text to scraped_pages/page_302.txt
# Scraping page 303...
# Saved text to scraped_pages/page_303.txt
# Scraping page 304...
# Saved text to scraped_pages/page_304.txt
# Scraping page 305...
# Saved text to scraped_pages/page_305.txt
# Scraping page 306...
# Saved text to scraped_pages/page_306.txt
# Scraping page 307...
# Saved text to scraped_pages/page_307.txt
# Scraping page 308...
# Saved text to scraped_pages/page_308.txt
# Scraping page 309...
# Saved text to scraped_pages/page_309.txt
# Scraping page 310...
# Saved text to scraped_pages/page_310.txt
# Scraping page 311...
# Saved text to scraped_pages/page_311.txt
# Scraping page 312...
# Saved text to scraped_pages/page_312.txt
# Scraping page 313...
# Saved text to scraped_pages/page_313.txt
# Scraping page 314...
# Saved text to scraped_pages/page_314.txt
# Scraping page 315...
# Saved text to scraped_pages/page_315.txt
# Scraping page 316...
# Saved text to scraped_pages/page_316.txt
# Scraping page 317...
# Saved text to scraped_pages/page_317.txt
# Scraping page 318...
# Saved text to scraped_pages/page_318.txt
# Scraping page 319...
# Saved text to scraped_pages/page_319.txt
# Scraping page 320...
# Saved text to scraped_pages/page_320.txt
# Scraping page 321...
# Saved text to scraped_pages/page_321.txt
# Scraping page 322...
# Saved text to scraped_pages/page_322.txt
# Scraping page 323...
# Saved text to scraped_pages/page_323.txt
# Scraping page 324...
# Saved text to scraped_pages/page_324.txt
# Scraping page 325...
# Saved text to scraped_pages/page_325.txt
# Scraping page 326...
# Saved text to scraped_pages/page_326.txt
# Scraping page 327...
# Saved text to scraped_pages/page_327.txt
# Scraping page 328...
# Saved text to scraped_pages/page_328.txt
# Scraping page 329...
# Saved text to scraped_pages/page_329.txt
# Scraping page 330...
# Saved text to scraped_pages/page_330.txt
# Scraping page 331...
# Saved text to scraped_pages/page_331.txt
# Scraping page 332...
# Saved text to scraped_pages/page_332.txt
# Scraping page 333...
# Saved text to scraped_pages/page_333.txt
# Scraping page 334...
# Saved text to scraped_pages/page_334.txt
# Scraping page 335...
# Saved text to scraped_pages/page_335.txt
# Scraping page 336...
# Saved text to scraped_pages/page_336.txt
# Scraping page 337...
# Saved text to scraped_pages/page_337.txt
# Scraping page 338...
# Saved text to scraped_pages/page_338.txt
# Scraping page 339...
# Saved text to scraped_pages/page_339.txt
# Scraping page 340...
# Saved text to scraped_pages/page_340.txt
# Scraping page 341...
# Saved text to scraped_pages/page_341.txt
# Scraping page 342...
# Saved text to scraped_pages/page_342.txt
# Scraping page 343...
# Saved text to scraped_pages/page_343.txt
# Scraping page 344...
# Saved text to scraped_pages/page_344.txt
# Scraping page 345...
# Saved text to scraped_pages/page_345.txt
# Scraping page 346...
# Saved text to scraped_pages/page_346.txt
# Scraping page 347...
# Saved text to scraped_pages/page_347.txt
# Scraping page 348...
# Saved text to scraped_pages/page_348.txt
# Scraping page 349...
# Saved text to scraped_pages/page_349.txt
# Scraping page 350...
# Saved text to scraped_pages/page_350.txt
# Scraping page 351...
# Saved text to scraped_pages/page_351.txt
# Scraping page 352...
# Saved text to scraped_pages/page_352.txt
# Scraping page 353...
# Saved text to scraped_pages/page_353.txt
# Scraping page 354...
# Saved text to scraped_pages/page_354.txt
# Scraping page 355...
# Saved text to scraped_pages/page_355.txt
# Scraping page 356...
# Saved text to scraped_pages/page_356.txt
# Scraping page 357...
# Saved text to scraped_pages/page_357.txt
# Scraping page 358...
# Saved text to scraped_pages/page_358.txt
# Scraping page 359...
# Saved text to scraped_pages/page_359.txt
# Scraping page 360...
# Saved text to scraped_pages/page_360.txt
# Scraping page 361...
# Saved text to scraped_pages/page_361.txt
# Scraping page 362...
# Saved text to scraped_pages/page_362.txt
# Scraping page 363...
# Saved text to scraped_pages/page_363.txt
# Scraping page 364...
# Saved text to scraped_pages/page_364.txt
# Scraping page 365...
# Saved text to scraped_pages/page_365.txt
# Scraping page 366...
# Saved text to scraped_pages/page_366.txt
# Scraping page 367...
# Saved text to scraped_pages/page_367.txt
# Scraping page 368...
# Saved text to scraped_pages/page_368.txt
# Scraping page 369...
# Saved text to scraped_pages/page_369.txt
# Scraping page 370...
# Saved text to scraped_pages/page_370.txt
# Scraping page 371...
# Saved text to scraped_pages/page_371.txt
# Scraping page 372...
# Saved text to scraped_pages/page_372.txt
# Scraping page 373...
# Saved text to scraped_pages/page_373.txt
# Scraping page 374...
# Saved text to scraped_pages/page_374.txt
# Scraping page 375...
# Saved text to scraped_pages/page_375.txt
# Scraping page 376...
# Saved text to scraped_pages/page_376.txt
# Scraping page 377...
# Saved text to scraped_pages/page_377.txt
# Scraping page 378...
# Saved text to scraped_pages/page_378.txt
# Scraping page 379...
# Saved text to scraped_pages/page_379.txt
# Scraping page 380...
# Saved text to scraped_pages/page_380.txt
# Scraping page 381...
# Saved text to scraped_pages/page_381.txt
# Scraping page 382...
# Saved text to scraped_pages/page_382.txt
# Scraping page 383...
# Saved text to scraped_pages/page_383.txt
# Scraping page 384...
# Saved text to scraped_pages/page_384.txt
# Scraping page 385...
# Saved text to scraped_pages/page_385.txt
# Scraping page 386...
# Saved text to scraped_pages/page_386.txt
# Scraping page 387...
# Saved text to scraped_pages/page_387.txt
# Scraping page 388...
# Saved text to scraped_pages/page_388.txt
# Scraping page 389...
# Saved text to scraped_pages/page_389.txt
# Scraping page 390...
# Saved text to scraped_pages/page_390.txt
# Scraping page 391...
# Saved text to scraped_pages/page_391.txt
# Scraping page 392...
# Saved text to scraped_pages/page_392.txt
# Scraping page 393...
# Saved text to scraped_pages/page_393.txt
# Scraping page 394...
# Saved text to scraped_pages/page_394.txt
# Scraping page 395...
# Saved text to scraped_pages/page_395.txt
# Scraping page 396...
# Saved text to scraped_pages/page_396.txt
# Scraping page 397...
# Saved text to scraped_pages/page_397.txt
# Scraping page 398...
# Saved text to scraped_pages/page_398.txt
# Scraping page 399...
# Saved text to scraped_pages/page_399.txt
# Scraping page 400...
# Saved text to scraped_pages/page_400.txt
# Scraping page 401...
# Saved text to scraped_pages/page_401.txt
# Scraping page 402...
# Saved text to scraped_pages/page_402.txt
# Scraping page 403...
# Saved text to scraped_pages/page_403.txt
# Scraping page 404...
# Saved text to scraped_pages/page_404.txt
# Scraping page 405...
# Saved text to scraped_pages/page_405.txt
# Scraping page 406...
# Saved text to scraped_pages/page_406.txt
# Scraping page 407...
# Saved text to scraped_pages/page_407.txt
# Scraping page 408...
# Saved text to scraped_pages/page_408.txt
# Scraping page 409...
# Saved text to scraped_pages/page_409.txt
# Scraping page 410...
# Saved text to scraped_pages/page_410.txt
# Scraping page 411...
# Saved text to scraped_pages/page_411.txt
# Scraping page 412...
# Saved text to scraped_pages/page_412.txt
# Scraping page 413...
# Saved text to scraped_pages/page_413.txt
# Scraping page 414...
# Saved text to scraped_pages/page_414.txt
# Scraping page 415...
# Saved text to scraped_pages/page_415.txt
# Scraping page 416...
# Saved text to scraped_pages/page_416.txt
# Scraping page 417...
# Saved text to scraped_pages/page_417.txt
# Scraping page 418...
# Saved text to scraped_pages/page_418.txt
# Scraping page 419...
# Saved text to scraped_pages/page_419.txt
# Scraping page 420...
# Saved text to scraped_pages/page_420.txt
# Scraping page 421...
# Saved text to scraped_pages/page_421.txt
# Scraping page 422...
# Saved text to scraped_pages/page_422.txt
# Scraping page 423...
# Saved text to scraped_pages/page_423.txt
# Scraping page 424...
# Saved text to scraped_pages/page_424.txt
# Scraping page 425...
# Saved text to scraped_pages/page_425.txt
# Scraping page 426...
# Saved text to scraped_pages/page_426.txt
# Scraping page 427...
# Saved text to scraped_pages/page_427.txt
# Scraping page 428...
# Saved text to scraped_pages/page_428.txt
# Scraping page 429...
# Saved text to scraped_pages/page_429.txt
# Scraping page 430...
# Saved text to scraped_pages/page_430.txt
# Scraping page 431...
# Saved text to scraped_pages/page_431.txt
# Scraping page 432...
# Saved text to scraped_pages/page_432.txt
# Scraping page 433...
# Saved text to scraped_pages/page_433.txt
# Scraping page 434...
# Saved text to scraped_pages/page_434.txt
# Scraping page 435...
# Saved text to scraped_pages/page_435.txt
# Scraping page 436...
# Saved text to scraped_pages/page_436.txt
# Scraping page 437...
# Saved text to scraped_pages/page_437.txt
# Scraping page 438...
# Saved text to scraped_pages/page_438.txt
# Scraping page 439...
# Saved text to scraped_pages/page_439.txt
# Scraping page 440...
# Saved text to scraped_pages/page_440.txt
# Scraping page 441...
# Saved text to scraped_pages/page_441.txt
# Scraping page 442...
# Saved text to scraped_pages/page_442.txt
# Scraping page 443...
# Saved text to scraped_pages/page_443.txt
# Scraping page 444...
# Saved text to scraped_pages/page_444.txt
# Scraping page 445...
# Saved text to scraped_pages/page_445.txt
# Scraping page 446...
# Saved text to scraped_pages/page_446.txt
# Scraping page 447...
# Saved text to scraped_pages/page_447.txt
# Scraping page 448...
# Saved text to scraped_pages/page_448.txt
# Scraping page 449...
# Saved text to scraped_pages/page_449.txt
# Scraping page 450...
# Saved text to scraped_pages/page_450.txt
# Scraping page 451...
# Saved text to scraped_pages/page_451.txt
# Scraping page 452...
# Saved text to scraped_pages/page_452.txt
# Scraping page 453...
# Saved text to scraped_pages/page_453.txt
# Scraping page 454...
# Saved text to scraped_pages/page_454.txt
# Scraping page 455...
# Saved text to scraped_pages/page_455.txt
# Scraping page 456...
# Saved text to scraped_pages/page_456.txt
# Scraping page 457...
# Saved text to scraped_pages/page_457.txt
# Scraping page 458...
# Saved text to scraped_pages/page_458.txt
# Scraping page 459...
# Saved text to scraped_pages/page_459.txt
# Scraping page 460...
# Saved text to scraped_pages/page_460.txt
# Scraping page 461...
# Saved text to scraped_pages/page_461.txt
# Scraping page 462...
# Saved text to scraped_pages/page_462.txt
# Scraping page 463...
# Saved text to scraped_pages/page_463.txt
# Scraping page 464...
# Saved text to scraped_pages/page_464.txt
# Scraping page 465...
# Saved text to scraped_pages/page_465.txt
# Scraping page 466...
# Saved text to scraped_pages/page_466.txt
# Scraping page 467...
# Saved text to scraped_pages/page_467.txt
# Scraping page 468...
# Saved text to scraped_pages/page_468.txt
# Scraping page 469...
# Saved text to scraped_pages/page_469.txt
# Scraping page 470...
# Saved text to scraped_pages/page_470.txt
# Scraping page 471...
# Saved text to scraped_pages/page_471.txt
# Scraping page 472...
# Saved text to scraped_pages/page_472.txt
# Scraping page 473...
# Saved text to scraped_pages/page_473.txt
# Scraping page 474...
# Saved text to scraped_pages/page_474.txt
# Scraping page 475...
# Saved text to scraped_pages/page_475.txt
# Scraping page 476...
# Saved text to scraped_pages/page_476.txt
# Scraping page 477...
# Saved text to scraped_pages/page_477.txt
# Scraping page 478...
# Saved text to scraped_pages/page_478.txt
# Scraping page 479...
# Saved text to scraped_pages/page_479.txt
# Scraping page 480...
# Saved text to scraped_pages/page_480.txt
# Scraping page 481...
# Saved text to scraped_pages/page_481.txt
# Scraping page 482...
# Saved text to scraped_pages/page_482.txt
# Scraping page 483...
# Saved text to scraped_pages/page_483.txt
# Scraping page 484...
# Saved text to scraped_pages/page_484.txt
# Scraping page 485...
# Saved text to scraped_pages/page_485.txt
# Scraping page 486...
# Saved text to scraped_pages/page_486.txt
# Scraping page 487...
# Saved text to scraped_pages/page_487.txt
# Scraping page 488...
# Saved text to scraped_pages/page_488.txt
# Scraping page 489...
# Saved text to scraped_pages/page_489.txt
# Scraping page 490...
# Saved text to scraped_pages/page_490.txt
# Scraping page 491...
# Saved text to scraped_pages/page_491.txt
# Scraping page 492...
# Saved text to scraped_pages/page_492.txt
# Scraping page 493...
# Saved text to scraped_pages/page_493.txt
# Scraping page 494...
# Saved text to scraped_pages/page_494.txt
# Scraping page 495...
# Saved text to scraped_pages/page_495.txt
# Scraping page 496...
# Saved text to scraped_pages/page_496.txt
# Scraping page 497...
# Saved text to scraped_pages/page_497.txt
# Scraping page 498...
# Saved text to scraped_pages/page_498.txt
# Scraping page 499...
# Saved text to scraped_pages/page_499.txt
# Analyzing similarities...
# Creating dataset...
# Dataset saved to dataset.csv

# %%
import pandas as pd

# Lire le fichier CSV en s'assurant d'utiliser le bon encodage
df = pd.read_csv("dataset.csv", encoding="utf-8")
print(df.head())
# Out:
#        Filename                                            Content  Score
# 0  page_123.txt  ﻿كووورة الموقع العربي الرياضي الأول أخبار جمال...   0.81
# 1   page_90.txt  ﻿كووورة الموقع العربي الرياضي الأول أخبار شباب...   0.95
# 2  page_459.txt  ﻿كووورة الموقع العربي الرياضي الأول أخبار لاعب...   0.57
# 3  page_194.txt  ﻿كووورة الموقع العربي الرياضي الأول أخبار محطا...   0.88
# 4   page_11.txt  ﻿كووورة الموقع العربي الرياضي الأول أخبار عودة...   0.59

# %%
import nltk

# Téléchargez le tokenizer "punkt" qui est nécessaire pour la tokenisation
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# Assurez-vous que les ressources nécessaires sont téléchargées
nltk.download('punkt')
nltk.download('stopwords')

# Charger le fichier CSV
df = pd.read_csv('dataset.csv')

# Prétraiter le texte
def preprocess_text(text):
    # Convertir en minuscules
    text = text.lower()

    # Retirer les chiffres et les caractères non-arabes
    text = re.sub(r'[^a-zA-Z\u0600-\u06FF\s]', '', text)

    # Tokenisation
    tokens = word_tokenize(text)

    # Enlever les stop words
    stop_words = set(stopwords.words('arabic'))  # Utilisation des stop words arabes
    tokens = [word for word in tokens if word not in stop_words]

    # Stemming (ici, nous utilisons le stemmer anglais par défaut, pour l'arabe il existe des solutions comme `farasa` ou `camel-stemmer`)
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(word) for word in tokens]

    # Joindre les tokens traités pour obtenir le texte final
    return ' '.join(tokens)

# Appliquer le prétraitement sur chaque texte dans la colonne 'Content'
df['Processed_Content'] = df['Content'].apply(preprocess_text)

# Sauvegarder le dataset mis à jour dans un nouveau fichier CSV
df.to_csv('processed_dataset.csv', index=False)

print("Prétraitement terminé et dataset sauvegardé.")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import torch

# Appliquer TF-IDF pour la vectorisation des textes
vectorizer = TfidfVectorizer(max_features=5000)  # Limite le nombre de features à 5000
X = vectorizer.fit_transform(df['Processed_Content']).toarray()

# Convertir en tensor PyTorch
X_tensor = torch.tensor(X, dtype=torch.float32)

# %%
from sklearn.model_selection import train_test_split

# Diviser les données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X_tensor, df['Score'].values, test_size=0.2, random_state=42)

# Convertir en tensors PyTorch
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

# %%
import torch.nn as nn

class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(LSTMModel, self).__init__()

        # Définir la couche LSTM
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        # Définir la couche de classification (Dense)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        # Passer par la couche LSTM
        lstm_out, (hn, cn) = self.lstm(x)
        # Utiliser la dernière sortie de la séquence pour la classification
        out = self.fc(hn[-1])
        return out

# %%
# Initialiser le modèle
input_size = X_train.shape[1]  # Le nombre de features (par exemple 5000)
hidden_size = 64  # Nombre d'unités cachées
output_size = 1  # Pour la classification binaire

model = LSTMModel(input_size, hidden_size, output_size)

# Définir la fonction de perte et l'optimiseur
criterion = nn.BCEWithLogitsLoss()  # Pour la classification binaire
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Entraînement
num_epochs = 5
for epoch in range(num_epochs):
    model.train()

    # Passer les données d'entraînement à travers le modèle
    outputs = model(X_train_tensor)

    # Calculer la perte
    loss = criterion(outputs.squeeze(), y_train_tensor)

    # Mettre à jour les poids
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}")

# %%
# Évaluation du modèle
model.eval()
with torch.no_grad():
    outputs = model(X_test_tensor)
    predicted = torch.round(torch.sigmoid(outputs.squeeze()))  # Convertir la sortie en classe binaire
    accuracy = (predicted == y_test_tensor).float().mean()
    print(f"Test Accuracy: {accuracy:.4f}")

# %%
# Pour prédire sur de nouvelles données
new_data = vectorizer.transform(["بدأ فريق ليستر سيتي مشواره تحت قيادة المدير الفني الجديد رود فان نيستلروي بالفوز على وست هام يونايتد"]).toarray()  # Exemple avec TF-IDF
new_data_tensor = torch.tensor(new_data, dtype=torch.float32)

# Prédiction
model.eval()
with torch.no_grad():
    output = model(new_data_tensor)
    prediction = torch.round(torch.sigmoid(output.squeeze()))  # Si la prédiction > 0.5, c'est 1 (positif)
    print(f"Prediction: {prediction.item()}")
